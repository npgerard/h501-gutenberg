# %%
# !conda env list
# Out:
# # conda environments:
# #
#                      * /Users/iumds/Library/CloudStorage/OneDrive-IndianaUniversity/GitHub/h501-gutenberg/.conda
# base                   /opt/anaconda3

# %%
from tt_gutenberg.authors import *
import pandas as pd

list_authors(by_languages=True, alias=False)
# Out:
# ['Grimm, Jacob',
#  'Grimm, Wilhelm',
#  'Wilde, Oscar',
#  'Stevenson, Robert Louis',
#  'Andersen, H. C. (Hans Christian)',
#  'Dante Alighieri',
#  'Homer',
#  'Poe, Edgar Allan',
#  'Carroll, Lewis',
#  'Plato',
#  'Swift, Jonathan',
#  'Maupassant, Guy de',
#  'London, Jack',
#  'Aimard, Gustave',
#  'Irving, Washington',
#  'Descartes, René',
#  'Darwin, Charles',
#  'Wells, H. G. (Herbert George)',
#  'Rolland, Romain',
#  'Schmid, Christoph von',
#  'Whitman, Walt',
#  'Mérimée, Prosper',
#  'Ohnet, Georges',
#  'Bunyan, John',
#  'Michelangelo Buonarroti',
#  'Michelet, Jules',
#  'Augustine, Saint, Bishop of Hippo',
#  'Wallace, Lew',
#  'Harte, Bret',
#  'Murger, Henri',
#  'Heine, Heinrich',
#  'Strindberg, August',
#  'Erasmus, Desiderius',
#  'Reuter, Fritz',
#  'Engels, Friedrich',
#  'Mill, John Stuart',
#  'Confucius',
#  'Racine, Jean',
#  'Ruskin, John',
#  'Chaucer, Geoffrey',
#  'Curwood, James Oliver',
#  'Zweig, Stefan',
#  'Daudet, Alphonse',
# ...
